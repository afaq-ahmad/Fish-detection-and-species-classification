# %%
import pickle
with open("categories_names.pickle", "rb") as input_file:
    classes = pickle.load(input_file)

# %%
classes
# Out:
# ['aculeatus',
#  'acuminatus',
#  'acutidens',
#  'adiergastos',
#  'adusta',
#  'affinis',
#  'albifasciatus',
#  'albimarginata',
#  'albimarginatus',
#  'albomarginata',
#  'altivelis',
#  'amblycephalum',
#  'amblyrhynchos',
#  'amboinensis',
#  'aneitensis',
#  'annulatus',
#  'aprinus',
#  'arcatus',
#  'areolatus',
#  'argenteus',
#  'argus',
#  'aruanus',
#  'assarius',
#  'atkinsoni',
#  'atripectoralis',
#  'aureofasciatus',
#  'aureolineatus',
#  'aureus',
#  'auricularis',
#  'auriga',
#  'auromarginatus',
#  'australiae',
#  'australis',
#  'axillaris',
#  'axiologus',
#  'aygula',
#  'azysron',
#  'baillonii',
#  'bandanensis',
#  'barberinoides',
#  'barberinus',
#  'bariene',
#  'barracuda',
#  'batavianus',
#  'bengalensis',
#  'bennetti',
#  'bicolor',
#  'bifasciatum',
#  'bigibbus',
#  'bilineata',
#  'bilobatus',
#  'bilunulatus',
#  'bimaculatus',
#  'binotatus',
#  'biocellata',
#  'biocellatus',
#  'bipinnulata',
#  'bleekeri',
#  'blochii',
#  'bohar',
# ...
